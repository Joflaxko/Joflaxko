# %% [markdown]
# <a href="https://colab.research.google.com/github/Joflaxko/Joflaxko/blob/main/Josiah_cai2100_assignment_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started with Python and Reading Data using Pandas

# %% [markdown]
# **Learning goals**
# - Read input and print friendly output
# - Use variables to store values
# - Understand core data types: `int`, `float`, `str`, `bool`
# - Use arithmetic and comparison operators

# %% [markdown]
# ### Exercise 1.1
#
# Write **three separate lines of Python code**.
# Each line should use the `print()` function to display to the screen:
#
# 1. Your name
# 2. Your address
# 3. Your phone number
#
# This exercise helps you practice the basic `print()` function.
#
# 💡 **Hint:** The `print()` function displays whatever you put inside the parentheses.
# For example:

# %%
print("Hello, world!")

# %% [markdown]
# ✅ **Your Turn:** Fill in your own details below:

# %%
# Replace the text inside the quotes with your own information
print("Josiah Ninah")
print("5571 Pecan RD")
print("5169991099")

# %% [markdown]
# ### Exercise 1.2
#
# Write a program that computes and prints the area of a rectangle, given an input width and height.
#
# Your program should compute the area using the formula below and print the result in a readable sentence. Use two variables to hold the values for width and height.
#
# The *area* is given by:
#
# $$ \text{area} = \text{width} \times \text{height} $$
#
# I am giving you some starter code. NOTE that whereever there is a ... this means there is something you need to fill in or modify there for the code to work.
#
# Have your code set the values:
# * width: 12
# * length: 4
#
# ✅ **Your Turn:** Fill in the missing code below:
#
# Remember, that for a line to run, you need to remove the pound (#) sign, otherwise Python thinks it is a comment

# %%
# Starter code to assign values to your variables
# width = 12
# height = 4

# Starter code for the computation
#area = 20

# Starter code to orint the result in a complete sentence
#print("The area is", ...)

# %% [markdown]
# ### Exercise 1.3
#
# Modify your rectangle area program from Exercise 1.2, but this time use an f-string to print the result in a complete sentence.
#
# Your program should:
# * Assign values to the variables width and height.
# * Compute the area using width * height.
# * **Print the result using an f-string** (instead of commas in print).
#
# 💡 Hint:
# An f-string lets you insert variable values directly into a string.
# Example:

# %%
# This is an example of using print with an f-string
name = "Alice"
print(f"Hello, {name}!")

# %% [markdown]
# ✅ **Your Turn:** Modify your code to print the answer using an f-string

# %%
# Programming Exercise 1.3
# Computes and prints the area of a rectangle using an f-string.

# Use your same code to assign values to your variables
# width = 12
# height = 4

# Use your same code to calculate the area
# area = 20

# Starter code to print the result in a complete sentence using f-string
#print(f" ... { ... } square units.")

# %% [markdown]
# ## Exercise 1.4
# Write python code to:
# * Prompt the user for two numbers, one at a time
# * Assign those to variable names
# * Convert the strings that come back from the input function to a numeric data type (either int or float)
# * Add the two numbers
# * Nicely display the answer
#
# Remember that you can prompt the user, and convert to a numeric (floating point number) data type all in one statement using the following syntax:

# %%
a = float(input("Enter the first number: "))
print("5", a)
print("Its data type is", type(7))
# Out:
# Enter the first number: 5
# 5 5.0
# Its data type is <class 'int'>

# %% [markdown]
# ✅ **Your Turn:** Write the code to prompt the user and add the two given numbers

# %%
# Put your code here below
#a = float(input("Enter the first number: "))
print("7", a)
print("Its data type is", type(10))
# Out:
# 7 5.0
# Its data type is <class 'int'>

# %% [markdown]
# ## Exercise 1.5
# Be sure to read [Section 1.5](https://openstax.org/books/principles-data-science/pages/1-5-data-science-with-python) of your textbook which provides more information on how to use the pandas library to read data.
#
# Here you will read and explore a data set that contains the top 10 daily shows and movies using the pandas library

# %%
# pandas is not part of standard python, so we need to import it
# For convenience, we alias it as 'pd' so we can reference it that way
# In most ML code, you will see it imported this way
import pandas as pd

# We are using the pandas 'read_csv' method to read the file and load it into a DataFrame
# We assign the dataframe to the variable called 'data'
data = pd.read_csv("netflix_daily_top_10.csv")

# In a notebook, if the last statement is just an object, the notebook will display it
data
# data.describe()
# Out:
#            As of  Rank Year to Date Rank Last Week Rank  \
# 0     2020-04-01     1                 1              1
# 1     2020-04-01     2                 2              -
# 2     2020-04-01     3                 3              2
# 3     2020-04-01     4                 4              -
# 4     2020-04-01     5                 5              4
# ...          ...   ...               ...            ...
# 7095  2022-03-11     6                 5              1
# 7096  2022-03-11     7                 7              2
# 7097  2022-03-11     8                 8              -
# 7098  2022-03-11     9                 9              7
# 7099  2022-03-11    10                10              -
#
#                              Title     Type Netflix Exclusive  \
# 0     Tiger King: Murder, Mayhem …  TV Show               Yes
# 1                            Ozark  TV Show               Yes
# 2                     All American  TV Show               NaN
# ...

# %% [markdown]
# ✅ Your Turn: Write code to find the average 'Viewership Score' and 'Days in Top 10'.
#
# Hint: One way is to use data.describe(), which is the [pandas.DataFrame.describe](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html) method

# %% [markdown]
# ## Save, download, and submit your notebook
# You can submit your file in one of two ways.
# * Share your Google colab notebook with me (you need to give permission) and submit the URL/link
# * Or you can download the file and submit the .ipynb file. Note that the .ipynb file extension stands for interactive python notebook.
#
# To submit a link to your notebook, click the Share button in the upper right. Under General Access, choose "Anyone with the link", click Done, and the Copy Link. You don't need to share specifically with my email address. Make sure you have given anyone access to the link, otherwise I cannot give you credit for the assignment.
#
# If you would like to submit the actual notebook file (and have a saved copy locally), do the following:
# - Colab autosaves to your Google Drive under **Colab Notebooks**.
# - You can download: **File → Download → Download .ipynb**.
# - Then upload the file to Canvas
